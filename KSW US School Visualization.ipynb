# %%
"""Jupyter notebook to interact with the KSW Schools map data.

This notebook uses the leaflets extention.  To start, use:

jupyter nbextension enable --py --sys-prefix ipyleaflet
jupyter notebook

For debugging purposes, run this kernel from the root directory
""" 


## Fetch the most recent school data information
import hohgwuhn.fetch as fetch
fetch.fetchData()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-91da5c1867d9> in <module>
#       9
#      10 ## Fetch the most recent school data information
# ---> 11 import fetch
#      12 fetch.fetchData()
#
# ModuleNotFoundError: No module named 'fetch'

# %%
## Uses the Google Maps Geocoding API, which costs $$$.  So don't run this by default.
import geocoder_googs as geocoder

geocoder.loadSchoolData()
# Out:
# Processing Mc Henry County College 8900 US Hwy 14 Crystal Lke, IL 60012
# Processing 415 East Main Street Galesburg, IL 61401
# Processing 4628 Old Grand Ave Gurnee. IL 60031
# Processing 220 West Side Public Square Knoxville, Il 61448
# Processing NEW!!! 120 East Euclid Avenue Monmouth, IL 61462
# Processing NEW!!! 802 S. Eldorado Road Suite A3 Bloomington, IL 61704
# Processing NEW Location! 122 S. 14th Street Pekin, IL 61554
# Processing 5221 N. Big Hollow Road Peoria, IL 61615
# Processing NEW!! 1227 Peoria Street Washington, IL 61571
# Processing 3542 Western Ave Connersville, IN 47331
# Processing 2190 West White River Bend Blvd. Suite B Muncie, IN 47303
# Processing 2023 Chester Blvd (YMCA) Richmond, IN 47374
# Processing 1018 Spruce Hills Dr Bettendorf, IA 52722
# Processing 427 North 3rd Street Le Claire, IA 52753
# Processing 5515 Davison Rd #7 Burton, MI 48509
# Processing 26751 John Road Madison Heights, MI 48071
# Processing 1200 Ryan Street Sault Ste. Marie, MI 49783
# Processing 14700 State Rd Springlake, MI 49456
# Processing 800 Transfer Road #34 St. Paul, MN 55104
# Processing 929 N. Main St. O' Fallon, MO 63366
# Processing #1 East Sutters Mill Road St. Peters, MO 63376
# Processing Cleveland Heights Recreation Center 1 Montecello Blvd.  Cleveland Heights, OH 44118
# Processing Christian Life Center 3489 Little York Rd. Dayton, OH 45414
# Processing 7900 Euclid Chardon Road Kirtland, OH 44094
# Processing Streetsboro Recreation Center 9184 St. Rt 43 Streetsboro, OH 44241
# Found 2 results for: Streetsboro Recreation Center 9184 St. Rt 43 Streetsboro, OH 44241
# Processing University of Wisconsin Eagle Heights Community Center 611 Eagle Heights Madison, WI 53705
# Processing NEW!!! 10 Main Street Williston, ND 58801
# Processing 605 Rhode Island Avenue NE Washigton DC 20019
# Processing 7905 Central Ave Capitol Heights, MD 20743
# Processing North Laurel Community Center 9411 Whiskey Botton Rd Laurel, MD 20723
# Processing NEW!!! 3170 German Chapel Road Prince Frederick, MD 20678
# Processing 386 High St Clinton, MA 01510
# Processing 54 Weibel Ave  Saratoga Springs, NY 12866
# Processing 396 Route 104 Ontario, NY 14519
# Processing 4081 West Main Street Williamson, NY 14589
# Processing 11807 West Main Street Wolcott, NY 14590
# Processing N.C. A&T State University 1601 East Market Street Greensboro, NC 27411
# Processing NEW!!! Luke AFB Bryant Fitness Center & Youth Center 14185 West Falcon Street Glendale, AZ 85309
# Processing NEW!!! 126 W. Desert Hills Phoenix, AZ 85086
# Processing NEW!!! 14465 RH Johnson Blvd Sun City West, AZ 85375
# Processing 2438 Sacramento Street Berkeley, CA
# Processing 201 SOUTH FIFTH ST DIXON, CA 95620
# Processing 4558 Dublin Blvd. Dublin, CA 94568
# Processing 2222 Francisco Blvd. El Dorado Hills, CA 95762
# Processing 127 Argall Way Nevada City, CA 95959
# Processing 432- B Main St Half Moon Bay, CA 94019
# Processing NEW!! Lake Park Clubhouse 1035 11th Street Huntington Beach, CA 92648
# Processing 17520 Lake Elizabeth Road Lake Hughes, CA 93532
# Processing 2010 First Street Lincoln, CA 95648
# Processing NEW LOCATION ! 347- 1 Street Los Altos, CA 94022
# Processing Burgess Recreation Center 700 Alma Street Menlo Park, CA 94025
# Processing 30 Rollins Road Millbrae, CA 94030 (650) 692-KICK (5425)
# Processing 38218 6th Street East Palmdale, CA 93550
# Processing 5690 Motherlode Drive Placerville, CA 95667
# Processing 2135 Roosevelt Ave  Redwood City, CA 94061
# Processing 320 Professional Drive, #150 Rohnert Park, CA 94928
# Processing Mather Sports Complex 3755 Schriever Ave Mather, CA 95655
# Processing NEW Location! 25 Lake Street San Francisco, CA 94118  415-868-KICK
# Processing 17321 Hesperian Blvd. San Lorenzo, CA 94580
# Processing 31 West 25th Avenue San Mateo, CA
# Processing 27831 Smyth Drive Valencia, CA 91355
# Processing New Location! Sherman Oaks East Valley Adult Center 5056 Van Nuys Boulevard Van Nuys, CA 91403
# Processing NEW!!! 13788A Foothill Blvd. Sylmar, CA 91342
# Processing 189 Leland Ave St San Fransico, CA
# Processing 420 Front Street Wheatland, CA 95692
# Processing 618 Cottonwood St. Woodland, CA
# Processing 236 Bridge St. Yuba City, CA 95991
# Processing 3112 Cavanaugh Road Fort Smith, AR 72903
# Processing University of Arkansas 5210 Grand Ave Ft Smith, AR 72913
# Found 2 results for: University of Arkansas 5210 Grand Ave Ft Smith, AR 72913
# Processing 1507 Highway 10 Greenwood, AR
# Processing 210 Martin St Jacksonville, AR 72076
# Found 2 results for: 210 Martin St Jacksonville, AR 72076
# Processing NEW! Baptist Church 220 Elm Street Mountainburg, AR 72946
# Found 2 results for: NEW! Baptist Church 220 Elm Street Mountainburg, AR 72946
# Processing 4106 Honeysuckle Rogers, AR 72758
# Processing Aderholt Fitness Center 259 Tully Street - Bldg 90517 Hurlburt Field, FL 32544
# Processing NEW!!! Belle Terre Swim and Racquet Club 73 Patricia Drive Palm Coast, FL 32164
# Processing 835 Gretna Blvd Gretna, LA 70053
# Processing International School of New Orleans 1400 Camp Street New Orleans, LA 70103
# Found 2 results for: International School of New Orleans 1400 Camp Street New Orleans, LA 70103
# Processing NEW!!! Xavier University 1 Drexel Drive New Orleans, LA 70125
# Found 2 results for: NEW!!! Xavier University 1 Drexel Drive New Orleans, LA 70125
# Processing Pryor Creek Recreational Center 1111 Southeast 9th Street Pryor, OK 74361
# Processing NEW location! 2051 Mahaney Ave. Tahlequah, OK 74464
# Processing NEW !!! Tinker Youth Center 4460 McNarney Ave Oklahoma City, OK 73145
# Processing 1107 North Murray Ave. Anderson, SC 29621
# Processing 1085 Old Clemson Hwy Seneca, SC 29672
# Processing 3015#C East Palmetto Street Florence, SC
# Processing 5314 Wade Hampton Blvd.  Taylors, SC 29687
# Processing Carolina School of Massage 1313A Miller Rd. Greenville, SC 29607
# Processing NEW!! 416 West Main Street Lake City, SC 29560
# Processing TENNESSEE University of Memphis Memphis, TN 38104
# Processing 2401 S. 7th Abilene, TX 79605
# Processing 900 FM 1462 ALVIN, TX 77511
# Processing AUSTIN EANES SCHOOL DISTRICT 601 Camp Craft Rd Austin, TX 78746
# Processing 6001 W. Williams Cannon, Suite 307 Austin, TX 78749
# Processing 2827 North Alexander Baytown, TX 77520
# Processing OPEN SOON ! 37131 IH 10 West Boerne, TX 78006
# Processing 1601 Alton Gloor Suite 110 Brownsville, TX 78521
# Processing Coming Soon in August 2017!  4747 FM 1463 Suite #900 Katy, Texas 77494
# Processing 15230 HWY 3 Webster, TX 77598
# Processing 4414 Cobalt Cross St. Katy, Texas 77493
# Processing 910 Russell Palmer Road Kingwood, TX 77339-1601
# Processing World HQ 37937 FM 1774 Magnolia, TX 77355
# Processing Murphy Community Center  205 N Murphy Road Murphy, TX 75094
# Processing New location to be announced soon.
# Found 0 results for: New location to be announced soon.
# Processing 114 W. Broadway Street Prosper, TX 75078 Dallas Metro Area
# Processing 1125 Crabb River Road Richmond, TX 77469
# Processing 6812 Bandera Rd #109 San Antonio, TX 78238-3552
# Processing 1149 Harry Wurzbach Rd. San Antonio, TX 78209-640 210-824-KICK(5425)
# Processing 5530 Walzem Road San Antonio, TX 78218
# Processing Coming soon in September 2017 1330 Aquarena Springs Dr. Suite 107 San Marcos, TX 78666
# Processing New Location!!! 506 Sawdust Road The Woodlands, TX 77380
# Processing 32215 Tamina Road Magnolia, TX 77354
# Processing 20295 F.M.2920 Rd. Tomball, TX 77377

# %%
## Snippet to process an individual address to see what we get from Geocoding

import hohgwuhn.geocoder_googs as geocoder
from pprint import pprint

api = geocoder.LimitedApiManager(30)
result =  api.get("Bldg. 109 Risner Fitness Center Kadena Air Base, Japan", "JP")
pprint(result)
pprint(result[0]['geometry']['location'])

geometry = result[0]['geometry']
pprint({
    'lat': geometry['location']['lat'],
    'lon': geometry['location']['lng'],
    'type': geometry['location_type'],
    'formatted_address': result[0]['formatted_address']
})
# Out:
#   Fetching Bldg. 109 Risner Fitness Center Kadena Air Base, Japan (JP)
#   Found 2 JP results for: Bldg. 109 Risner Fitness Center Kadena Air Base, Japan
# [{'address_components': [{'long_name': 'Okinawa',
#                           'short_name': 'Okinawa',
#                           'types': ['locality', 'political']},
#                          {'long_name': 'Yamauchi',
#                           'short_name': 'Yamauchi',
#                           'types': ['political',
#                                     'sublocality',
#                                     'sublocality_level_2']},
#                          {'long_name': 'Okinawa',
#                           'short_name': 'Okinawa',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'Japan',
#                           'short_name': 'JP',
#                           'types': ['country', 'political']},
#                          {'long_name': '904-0000',
#                           'short_name': '904-0000',
#                           'types': ['postal_code']}],
#   'formatted_address': 'Yamauchi, Okinawa, 904-0000, Japan',
#   'geometry': {'location': {'lat': 26.3395214, 'lng': 127.7749353},
#                'location_type': 'GEOMETRIC_CENTER',
#                'viewport': {'northeast': {'lat': 26.3408703802915,
#                                           'lng': 127.7762842802915},
#                             'southwest': {'lat': 26.3381724197085,
#                                           'lng': 127.7735863197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJyScC2jcS5TQRF7ID3dD2AW4',
#   'plus_code': {'compound_code': '8QQF+RX Okinawa, Japan',
#                 'global_code': '7QR98QQF+RX'},
#   'types': ['establishment', 'gym', 'health', 'point_of_interest']},
#  {'address_components': [{'long_name': 'Japan',
#                           'short_name': 'JP',
#                           'types': ['country', 'political']},
#                          {'long_name': 'Azahigashi',
#                           'short_name': 'Azahigashi',
#                           'types': ['political',
#                                     'sublocality',
#                                     'sublocality_level_2']},
#                          {'long_name': 'Kadena',
#                           'short_name': 'Kadena',
#                           'types': ['locality', 'political']},
#                          {'long_name': 'Nakagami District',
#                           'short_name': 'Nakagami District',
#                           'types': ['administrative_area_level_2',
#                                     'political']},
#                          {'long_name': 'Okinawa',
#                           'short_name': 'Okinawa',
#                           'types': ['administrative_area_level_1',
#                                     'political']}],
#   'formatted_address': 'Azahigashi, Kadena, Nakagami District, Okinawa, Japan',
#   'geometry': {'location': {'lat': 26.3556897, 'lng': 127.7678754},
#                'location_type': 'GEOMETRIC_CENTER',
#                'viewport': {'northeast': {'lat': 26.35703868029151,
#                                           'lng': 127.7692243802915},
#                             'southwest': {'lat': 26.3543407197085,
#                                           'lng': 127.7665264197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJ6ypdpi4S5TQRpph-c1CUQmg',
#   'plus_code': {'compound_code': '9Q49+75 Kadena, Okinawa, Japan',
#                 'global_code': '7QR99Q49+75'},
#   'types': ['establishment', 'point_of_interest']}]
# {'lat': 26.3395214, 'lng': 127.7749353}
# {'formatted_address': 'Yamauchi, Okinawa, 904-0000, Japan',
#  'lat': 26.3395214,
#  'lon': 127.7749353,
#  'type': 'GEOMETRIC_CENTER'}

# %%
## Snippet to process a test segment of the file to debug errors in parsing on GCP
# Edit the `test_School_data.csv file before executing this

import hohgwuhn.fetch_wksa as fetch
import hohgwuhn.geocoder_googs as geocoder
from pprint import pprint

fetch.SCHOOL_EXPORT_FILE = 'data/test_school_data.csv'
geocoder.SCHOOL_GEODATA_FILE = 'data/test_school_geodata.csv'
geocoder.loadSchoolData()
# Out:
# Processing Bldg. 109 Risner Fitness Center Kadena Air Base, Japan 81-6117-34-5128
#   Fetching Bldg. 109 Risner Fitness Center Kadena Air Base, Japan 81-6117-34-5128 (JP)
#   Found 2 JP results for: Bldg. 109 Risner Fitness Center Kadena Air Base, Japan 81-6117-34-5128
#   Fetching Kadena AFB, Kadena Afb (JP)
#   Found 1 JP results for: Kadena AFB, Kadena Afb
# Processing Bld 1044 Misawa Air Base, Japan 011-81-176-66-8203
#   Fetching Bld 1044 Misawa Air Base, Japan 011-81-176-66-8203 (JP)
#   Found 2 JP results for: Bld 1044 Misawa Air Base, Japan 011-81-176-66-8203
#   Fetching Misawa AFB, Misawa Afb (JP)
#   Found 2 JP results for: Misawa AFB, Misawa Afb
# Processing Hollywoodlaan 109 Almere Stad Flevoland
#   Fetching Hollywoodlaan 109 Almere Stad Flevoland (NL)
#   Found 1 NL results for: Hollywoodlaan 109 Almere Stad Flevoland

# %%
## Snippet to visualize the map locally with ipyleaflet

import csv

import ipyleaflet
from ipyleaflet import Map, Marker, MarkerCluster

import geocoder


m = Map(center=[38, -95], zoom=4)

markers = []
with open(geocoder.SCHOOL_GEODATA_FILE, 'rb') as csv_in:
    school_data = csv.DictReader(csv_in)
    for school in school_data:
        marker = Marker(location=(school['Latitude'], school['Longitude']), title=school['Address'])
        markers.append(marker)
        
for marker in markers:
    m += marker
m
# Out:
# TWFwKGJhc2VtYXA9eyd1cmwnOiAnaHR0cHM6Ly97c30udGlsZS5vcGVuc3RyZWV0bWFwLm9yZy97en0ve3h9L3t5fS5wbmcnLCAnbWF4X3pvb20nOiAxOSwgJ2F0dHJpYnV0aW9uJzogJ01hcCDigKY=

# %%
## Snippet to view the Geodata file after it has been generated

with open(geocoder.SCHOOL_GEODATA_FILE, 'rb') as csv_in:
    from pprint import pprint
    school_data = csv.DictReader(csv_in)
    for school in school_data:
        pprint(school)
# Out:
# {'Address': 'Mc Henry County College 8900 US Hwy 14 Crystal Lke, IL 60012',
#  'City': 'Crystal Lake',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '8900 US-14, Crystal Lake, IL 60012, USA',
#  'Instructor': 'PKJN Tim Seitz',
#  'Latitude': '42.26001979999999',
#  'Longitude': '-88.3685333',
#  'Phone #s': '(847) 962-8600',
#  'Region': 'Illinois'}
# {'Address': '415 East Main Street Galesburg, IL 61401',
#  'City': 'Galesburg',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '415 E Main St, Galesburg, IL 61401, USA',
#  'Instructor': 'JDKJN Ed Sanchez',
#  'Latitude': '40.947592',
#  'Longitude': '-90.3643311',
#  'Phone #s': '(309) 342-6222',
#  'Region': 'Illinois'}
# {'Address': '4628 Old Grand Ave Gurnee. IL 60031',
#  'City': 'Gurnee',
#  'Geocode Type': 'RANGE_INTERPOLATED',
#  'Google Address': '4628 Old Grand Ave, Gurnee, IL 60031, USA',
#  'Instructor': 'PKJN Tim Seitz',
#  'Latitude': '42.3719846',
#  'Longitude': '-87.9187721',
#  'Phone #s': '(847) 962-8600',
#  'Region': 'Illinois'}
# {'Address': '220 West Side Public Square Knoxville, Il 61448',
#  'City': 'Knoxville',
#  'Geocode Type': 'GEOMETRIC_CENTER',
#  'Google Address': 'S Public Square, Knoxville, IL 61448, USA',
#  'Instructor': 'PKJN Joshua Smith',
#  'Latitude': '40.9079433',
#  'Longitude': '-90.2849968',
#  'Phone #s': '(309) 289-9757',
#  'Region': 'Illinois'}
# {'Address': 'NEW!!! 120 East Euclid Avenue Monmouth, IL 61462',
#  'City': 'Monmouth',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '120 E Euclid Ave, Monmouth, IL 61462, USA',
#  'Instructor': 'Inst. Randy Timmerman',
#  'Latitude': '40.9174656',
#  'Longitude': '-90.6471098',
#  'Phone #s': '(309) 335-5697',
#  'Region': 'Illinois'}
# {'Address': 'NEW!!! 802 S. Eldorado Road Suite A3 Bloomington, IL 61704',
#  'City': 'Normal',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '802 S Eldorado Rd A3, Bloomington, IL 61704, USA',
#  'Instructor': 'Inst. Megan Farris',
#  'Latitude': '40.4700137',
#  'Longitude': '-88.95219689999999',
#  'Phone #s': '(309) 229-1551',
#  'Region': 'Illinois'}
# {'Address': 'NEW Location! 122 S. 14th Street Pekin, IL 61554',
#  'City': 'Pekin',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '122 S 14th St, Pekin, IL 61554, USA',
#  'Instructor': 'Inst. Michael Yates',
#  'Latitude': '40.5665985',
#  'Longitude': '-89.6310192',
#  'Phone #s': '(309) 346-3466',
#  'Region': 'Illinois'}
# {'Address': '5221 N. Big Hollow Road Peoria, IL 61615',
#  'City': 'Peoria',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '5221 N Big Hollow Rd, Peoria, IL 61615, USA',
#  'Instructor': 'PKJN Ben Mitchell',
#  'Latitude': '40.7513381',
#  'Longitude': '-89.6366572',
#  'Phone #s': '(309) 692-0144',
#  'Region': 'Illinois'}
# {'Address': 'NEW!! 1227 Peoria Street Washington, IL 61571',
#  'City': 'Washington',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1227 Peoria St, Washington, IL 61571, USA',
#  'Instructor': 'Inst. Troi Westbrook',
#  'Latitude': '40.70333309999999',
#  'Longitude': '-89.4260867',
#  'Phone #s': '(309) 292-7101',
#  'Region': 'Illinois'}
# {'Address': '3542 Western Ave Connersville, IN 47331',
#  'City': 'Connersville',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '3542 Western Ave, Connersville, IN 47331, USA',
#  'Instructor': 'Inst.Benjamin Klein',
#  'Latitude': '39.67671',
#  'Longitude': '-85.137948',
#  'Phone #s': '(765) 993-8315',
#  'Region': 'Indiana'}
# {'Address': '2190 West White River Bend Blvd. Suite B Muncie, IN 47303',
#  'City': 'Muncie',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '2190 W White River Blvd Suite B, Muncie, IN 47303, USA',
#  'Instructor': 'Inst. Ken Ring',
#  'Latitude': '40.1870315',
#  'Longitude': '-85.4114203',
#  'Phone #s': '(765) 212-2591',
#  'Region': 'Indiana'}
# {'Address': '2023 Chester Blvd (YMCA) Richmond, IN 47374',
#  'City': 'Richmond',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1215 S J St, Richmond, IN 47374, USA',
#  'Instructor': 'PKJN Gary Phillips',
#  'Latitude': '39.815155',
#  'Longitude': '-84.88579179999999',
#  'Phone #s': '(765) 969-3334',
#  'Region': 'Indiana'}
# {'Address': '1018 Spruce Hills Dr Bettendorf, IA 52722',
#  'City': 'Bettendorf',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1018 Spruce Hills Dr, Bettendorf, IA 52722, USA',
#  'Instructor': 'JIKJN Jeff Green',
#  'Latitude': '41.5547403',
#  'Longitude': '-90.51666349999999',
#  'Phone #s': '(563) 505-5289',
#  'Region': 'Iowa'}
# {'Address': '427 North 3rd Street Le Claire, IA 52753',
#  'City': 'Le Claire',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '427 N 3rd St, Le Claire, IA 52753, USA',
#  'Instructor': 'JIKJN Jeff Green',
#  'Latitude': '41.6013233',
#  'Longitude': '-90.3467074',
#  'Phone #s': '(563) 505-5289',
#  'Region': 'Iowa'}
# {'Address': '5515 Davison Rd #7 Burton, MI 48509',
#  'City': 'Burton',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '5515 Davison Rd #7, Burton, MI 48509, USA',
#  'Instructor': 'PKJN Ken Wright',
#  'Latitude': '43.034365',
#  'Longitude': '-83.59671469999999',
#  'Phone #s': '(810) 908-2659',
#  'Region': 'Michigan'}
# {'Address': '26751 John Road Madison Heights, MI 48071',
#  'City': 'Madison Heights',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '26751 John R Rd, Madison Heights, MI 48071, USA',
#  'Instructor': 'Inst. Gehrik Mohr',
#  'Latitude': '42.4897503',
#  'Longitude': '-83.1054858',
#  'Phone #s': '(248) 291-7157',
#  'Region': 'Michigan'}
# {'Address': '1200 Ryan Street Sault Ste. Marie, MI 49783',
#  'City': 'Sault Ste. Marie',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1200 Ryan Ave, Sault Ste. Marie, MI 49783, USA',
#  'Instructor': 'JIKJN Karl Stolt',
#  'Latitude': '46.4900404',
#  'Longitude': '-84.3595776',
#  'Phone #s': '(906) 630-1929',
#  'Region': 'Michigan'}
# {'Address': '14700 State Rd Springlake, MI 49456',
#  'City': 'Spring Lake',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '14700 State Rd, Spring Lake, MI 49456, USA',
#  'Instructor': 'Inst. Sam Ferrell',
#  'Latitude': '43.0863101',
#  'Longitude': '-86.15307729999999',
#  'Phone #s': '(616) 795-3048',
#  'Region': 'Michigan'}
# {'Address': '800 Transfer Road #34 St. Paul, MN 55104',
#  'City': 'St. Paul',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '800 Transfer Rd #34, St Paul, MN 55114, USA',
#  'Instructor': 'PKJN. Steffen Kellogg',
#  'Latitude': '44.9651852',
#  'Longitude': '-93.18500399999999',
#  'Phone #s': '(651) 645-1455',
#  'Region': 'Minnesota'}
# {'Address': "929 N. Main St. O' Fallon, MO 63366",
#  'City': "O' Fallon",
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': "929 N Main St, O'Fallon, MO 63366, USA",
#  'Instructor': 'PKJN. Kelly  Fleites',
#  'Latitude': '38.82086049999999',
#  'Longitude': '-90.7002552',
#  'Phone #s': '(636) 978-5425',
#  'Region': 'Missouri'}
# {'Address': '#1 East Sutters Mill Road St. Peters, MO 63376',
#  'City': 'St. Louis',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1 Sutters Mill Rd, St Peters, MO 63376, USA',
#  'Instructor': 'JDKJN Jack Harvey',
#  'Latitude': '38.7791114',
#  'Longitude': '-90.5774812',
#  'Phone #s': '(636) 928-0035',
#  'Region': 'Missouri'}
# {'Address': 'Cleveland Heights Recreation Center 1 Montecello Blvd.  Cleveland Heights, OH 44118',
#  'City': 'Cleveland',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1 Monticello Blvd, Cleveland, OH 44118, USA',
#  'Instructor': 'Inst. David Pritts',
#  'Latitude': '41.5156983',
#  'Longitude': '-81.572648',
#  'Phone #s': '(216) 501-3063',
#  'Region': 'Ohio'}
# {'Address': 'Christian Life Center 3489 Little York Rd. Dayton, OH 45414',
#  'City': 'Dayton',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '3489 Little York Rd, Dayton, OH 45414, USA',
#  'Instructor': 'Inst. Cindy Redolfi',
#  'Latitude': '39.86342',
#  'Longitude': '-84.211535',
#  'Phone #s': '(937) 836-2149',
#  'Region': 'Ohio'}
# {'Address': '7900 Euclid Chardon Road Kirtland, OH 44094',
#  'City': 'Kirtland',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '7900 Euclid Chardon Rd, Kirtland, OH 44094, USA',
#  'Instructor': 'Inst. David Pritts',
#  'Latitude': '41.582322',
#  'Longitude': '-81.36097199999999',
#  'Phone #s': '(216) 501-3063',
#  'Region': 'Ohio'}
# {'Address': 'Streetsboro Recreation Center 9184 St. Rt 43 Streetsboro, OH 44241',
#  'City': 'Streetsboro',
#  'Geocode Type': 'APPROXIMATE',
#  'Google Address': 'Streetsboro, OH, USA',
#  'Instructor': 'PKJN Bob Williams',
#  'Latitude': '41.2392227',
#  'Longitude': '-81.3459405',
#  'Phone #s': '(440) 336-2833',
#  'Region': 'Ohio'}
# {'Address': 'University of Wisconsin Eagle Heights Community Center 611 Eagle Heights Madison, WI 53705',
#  'City': 'Madison',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '611 Eagle Heights Dr, Madison, WI 53705, USA',
#  'Instructor': 'Inst. Max Magee',
#  'Latitude': '43.08825969999999',
#  'Longitude': '-89.43648929999999',
#  'Phone #s': '(281) 253-7944',
#  'Region': 'Wisconsin'}
# {'Address': 'NEW!!! 10 Main Street Williston, ND 58801',
#  'City': 'Williston, ND',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '10 Main St, Williston, ND 58801, USA',
#  'Instructor': 'Inst.Audrey Kalil',
#  'Latitude': '48.1438705',
#  'Longitude': '-103.6206436',
#  'Phone #s': '(612) 387-0393',
#  'Region': 'Wisconsin'}
# {'Address': '605 Rhode Island Avenue NE Washigton DC 20019',
#  'City': 'Washington',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '605 Rhode Island Ave NE, Washington, DC 20002, USA',
#  'Instructor': 'Inst. Russell Moore',
#  'Latitude': '38.9203348',
#  'Longitude': '-76.99769700000002',
#  'Phone #s': '(301) 801-4398',
#  'Region': 'District of columbia'}
# {'Address': '7905 Central Ave Capitol Heights, MD 20743',
#  'City': 'Capitol Heights',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '7905 Central Ave, Capitol Heights, MD 20743, USA',
#  'Instructor': 'PKJN. Marlin Godfrey',
#  'Latitude': '38.8885986',
#  'Longitude': '-76.8694611',
#  'Phone #s': '(202) 437-2548',
#  'Region': 'Maryland'}
# {'Address': 'North Laurel Community Center 9411 Whiskey Botton Rd Laurel, MD 20723',
#  'City': 'N. Laurel',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '9411 Whiskey Bottom Rd, Laurel, MD 20723, USA',
#  'Instructor': 'Inst. Darren Fulmore',
#  'Latitude': '39.1161362',
#  'Longitude': '-76.8361479',
#  'Phone #s': '(301) 509-2030',
#  'Region': 'Maryland'}
# {'Address': 'NEW!!! 3170 German Chapel Road Prince Frederick, MD 20678',
#  'City': 'Prince Frederick',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '3170 German Chapel Rd, Prince Frederick, MD 20678, USA',
#  'Instructor': 'Inst. Andrew Eason',
#  'Latitude': '38.5251411',
#  'Longitude': '-76.6157283',
#  'Phone #s': '(443) 624-1808',
#  'Region': 'Maryland'}
# {'Address': '386 High St Clinton, MA 01510',
#  'City': 'Clinton',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '386 High St, Clinton, MA 01510, USA',
#  'Instructor': 'Inst. Kenneth Schalk',
#  'Latitude': '42.4225752',
#  'Longitude': '-71.6839306',
#  'Phone #s': '(978) 706-1779',
#  'Region': 'Massachusetts'}
# {'Address': '54 Weibel Ave  Saratoga Springs, NY 12866',
#  'City': 'Saratoga Springs',
#  'Geocode Type': 'RANGE_INTERPOLATED',
#  'Google Address': '54 Weibel Ave, Saratoga Springs, NY 12866, USA',
#  'Instructor': 'Inst. Jason Tetu',
#  'Latitude': '43.0967726',
#  'Longitude': '-73.7448247',
#  'Phone #s': '(518) 242-9968',
#  'Region': 'New york'}
# {'Address': '396 Route 104 Ontario, NY 14519',
#  'City': 'Webster',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '396 NY-104, Ontario, NY 14519, USA',
#  'Instructor': 'JDKJN Gary Evarts',
#  'Latitude': '43.2247422',
#  'Longitude': '-77.359948',
#  'Phone #s': '(585) 216-2122',
#  'Region': 'New york'}
# {'Address': '4081 West Main Street Williamson, NY 14589',
#  'City': 'Williamson',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '4081 Main St, Williamson, NY 14589, USA',
#  'Instructor': 'JDKJN Gary Evarts',
#  'Latitude': '43.22391',
#  'Longitude': '-77.1868255',
#  'Phone #s': '(315) 589-4066',
#  'Region': 'New york'}
# {'Address': '11807 West Main Street Wolcott, NY 14590',
#  'City': 'Wolcott',
#  'Geocode Type': 'RANGE_INTERPOLATED',
#  'Google Address': '11807 W Main St, Wolcott, NY 14590, USA',
#  'Instructor': 'JIKJN Joseph Burnett',
#  'Latitude': '43.2238496',
#  'Longitude': '-76.8244564',
#  'Phone #s': '(315) 594-8991',
#  'Region': 'New york'}
# {'Address': 'N.C. A&T State University 1601 East Market Street Greensboro, NC 27411',
#  'City': 'Greensboro',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '120 Gibbs Hall, 1601 E Market St, Greensboro, NC 27411, USA',
#  'Instructor': 'PKJN Steve Hurley',
#  'Latitude': '36.0727791',
#  'Longitude': '-79.7733641',
#  'Phone #s': '',
#  'Region': 'North carolina'}
# {'Address': 'NEW!!! Luke AFB Bryant Fitness Center & Youth Center 14185 West Falcon Street Glendale, AZ 85309',
#  'City': 'Luke AFB',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '14053 W Shooting Star, Glendale, AZ 85309, USA',
#  'Instructor': 'Inst. Angela Hoikka',
#  'Latitude': '33.5338846',
#  'Longitude': '-112.3599483',
#  'Phone #s': '(623) 337-0258',
#  'Region': 'Arizona'}
# {'Address': 'NEW!!! 126 W. Desert Hills Phoenix, AZ 85086',
#  'City': 'Phoenix',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '126 W Desert Hills Dr, Phoenix, AZ 85086, USA',
#  'Instructor': 'Inst. Angela Hoikka',
#  'Latitude': '33.8442426',
#  'Longitude': '-112.077119',
#  'Phone #s': '(623) 337-0258',
#  'Region': 'Arizona'}
# {'Address': 'NEW!!! 14465 RH Johnson Blvd Sun City West, AZ 85375',
#  'City': 'Surprise/ Sun Ciity West',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '14465 W R H Johnson Blvd, Sun City West, AZ 85375, USA',
#  'Instructor': 'JIKJN Terry Heaps',
#  'Latitude': '33.6694225',
#  'Longitude': '-112.3706139',
#  'Phone #s': '(623) 518-0056',
#  'Region': 'Arizona'}
# {'Address': '2438 Sacramento Street Berkeley, CA',
#  'City': 'Berkeley',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '2438 Sacramento St, Berkeley, CA 94702, USA',
#  'Instructor': 'JDKJN Tom Brewer',
#  'Latitude': '37.8625611',
#  'Longitude': '-122.2814939',
#  'Phone #s': '(510) 540-8070',
#  'Region': 'California'}
# {'Address': '201 SOUTH FIFTH ST DIXON, CA 95620',
#  'City': 'DIXON',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '201 S 5th St, Dixon, CA 95620, USA',
#  'Instructor': 'Inst. Tiffany Bunn',
#  'Latitude': '38.444632',
#  'Longitude': '-121.81705',
#  'Phone #s': '(530) 908-0756',
#  'Region': 'California'}
# {'Address': '4558 Dublin Blvd. Dublin, CA 94568',
#  'City': 'Dublin',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '4558 Dublin Blvd, Dublin, CA 94568, USA',
#  'Instructor': 'JIKJN Seyd Saidi',
#  'Latitude': '37.7048401',
#  'Longitude': '-121.8811595',
#  'Phone #s': '(925) 551-8200',
#  'Region': 'California'}
# {'Address': '2222 Francisco Blvd. El Dorado Hills, CA 95762',
#  'City': 'El Dorado Hills',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '600, 2222 Francisco Dr, El Dorado Hills, CA 95762, USA',
#  'Instructor': 'PKJN Justin Painter',
#  'Latitude': '38.710469',
#  'Longitude': '-121.0863537',
#  'Phone #s': '(530) 642-9031',
#  'Region': 'California'}
# {'Address': '127 Argall Way Nevada City, CA 95959',
#  'City': 'Gold Country',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '127 Argall Way, Nevada City, CA 95959, USA',
#  'Instructor': 'JIKJN Tony Reyna',
#  'Latitude': '39.2523558',
#  'Longitude': '-121.024882',
#  'Phone #s': '(530) 478-1412',
#  'Region': 'California'}
# {'Address': '432- B Main St Half Moon Bay, CA 94019',
#  'City': 'Half Moon Bay',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '432B Main St, Half Moon Bay, CA 94019, USA',
#  'Instructor': 'JIKJN Paul Carmody',
#  'Latitude': '37.464039',
#  'Longitude': '-122.429332',
#  'Phone #s': '(650) 726-4132',
#  'Region': 'California'}
# {'Address': 'NEW!! Lake Park Clubhouse 1035 11th Street Huntington Beach, CA 92648',
#  'City': 'Huntington Beach',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1035 11th St, Huntington Beach, CA 92648, USA',
#  'Instructor': 'JIKJN Gene Gause',
#  'Latitude': '33.668639',
#  'Longitude': '-117.99919',
#  'Phone #s': '(661) 644-6514',
#  'Region': 'California'}
# {'Address': '17520 Lake Elizabeth Road Lake Hughes, CA 93532',
#  'City': 'Lake Hughes',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '17520 Elizabeth Lake Rd, Lake Hughes, CA 93532, USA',
#  'Instructor': 'PKJN David Collins',
#  'Latitude': '34.6730407',
#  'Longitude': '-118.4397326',
#  'Phone #s': '(661) 202-8085',
#  'Region': 'California'}
# {'Address': '2010 First Street Lincoln, CA 95648',
#  'City': 'Lincoln',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '2010 1st St, Lincoln, CA 95648, USA',
#  'Instructor': 'Inst. John Santilena',
#  'Latitude': '38.8875157',
#  'Longitude': '-121.3144153',
#  'Phone #s': '(916) 253-3801',
#  'Region': 'California'}
# {'Address': 'NEW LOCATION ! 347- 1 Street Los Altos, CA 94022',
#  'City': 'Los Altos',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '347 1st St, Los Altos, CA 94022, USA',
#  'Instructor': 'JIKJN.David Hespelt',
#  'Latitude': '37.37664300000001',
#  'Longitude': '-122.11641',
#  'Phone #s': '(650) 938-1553',
#  'Region': 'California'}
# {'Address': 'Burgess Recreation Center 700 Alma Street Menlo Park, CA 94025',
#  'City': 'Menlo Park',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '700 Alma St, Menlo Park, CA 94025, USA',
#  'Instructor': 'PKJN. Kristin Quintana',
#  'Latitude': '37.4527885',
#  'Longitude': '-122.1781954',
#  'Phone #s': '(650) 787-2226',
#  'Region': 'California'}
# {'Address': '30 Rollins Road Millbrae, CA 94030 (650) 692-KICK (5425)',
#  'City': 'Millbrae',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '30 Rollins Rd, Millbrae, CA 94030, USA',
#  'Instructor': 'Inst. Dong Nguyen',
#  'Latitude': '37.5993939',
#  'Longitude': '-122.383542',
#  'Phone #s': '',
#  'Region': 'California'}
# {'Address': '38218 6th Street East Palmdale, CA 93550',
#  'City': 'Palmdale',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '38218 6th St E, Palmdale, CA 93550, USA',
#  'Instructor': 'PKJN Antony Kinzell',
#  'Latitude': '34.5756624',
#  'Longitude': '-118.1174228',
#  'Phone #s': '(661) 947-3992;(661) 273-3235',
#  'Region': 'California'}
# {'Address': '5690 Motherlode Drive Placerville, CA 95667',
#  'City': 'Placerville',
#  'Geocode Type': 'RANGE_INTERPOLATED',
#  'Google Address': '5690 Mother Lode Dr, Placerville, CA 95667, USA',
#  'Instructor': 'PKJN Justin Painter',
#  'Latitude': '38.6800584',
#  'Longitude': '-120.8694712',
#  'Phone #s': '',
#  'Region': 'California'}
# {'Address': '2135 Roosevelt Ave  Redwood City, CA 94061',
#  'City': 'Redwood City',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '2135 Roosevelt Ave, Redwood City, CA 94061, USA',
#  'Instructor': 'JDKJN Hafez Adle',
#  'Latitude': '37.4660599',
#  'Longitude': '-122.2410515',
#  'Phone #s': '(650) 368-2761',
#  'Region': 'California'}
# {'Address': '320 Professional Drive, #150 Rohnert Park, CA 94928',
#  'City': 'Rohnert Park',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '320 Professional Center Dr #150, Rohnert Park, CA 94928, USA',
#  'Instructor': 'PKJN Debra Taylor',
#  'Latitude': '38.3556738',
#  'Longitude': '-122.7067741',
#  'Phone #s': '(707) 494-1151',
#  'Region': 'California'}
# {'Address': 'Mather Sports Complex 3755 Schriever Ave Mather, CA 95655',
#  'City': 'Sacramento',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '3755 Schriever Ave, Mather, CA 95655, USA',
#  'Instructor': 'PKJN. Kymberly Wadsworth',
#  'Latitude': '38.571255',
#  'Longitude': '-121.301653',
#  'Phone #s': '(916) 308-6577',
#  'Region': 'California'}
# {'Address': 'NEW Location! 25 Lake Street San Francisco, CA 94118  415-868-KICK',
#  'City': 'San Francisco',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '25 Lake St, San Francisco, CA 94118, USA',
#  'Instructor': 'PKJN. Leora Goren',
#  'Latitude': '37.7867097',
#  'Longitude': '-122.4598082',
#  'Phone #s': '',
#  'Region': 'California'}
# {'Address': '17321 Hesperian Blvd. San Lorenzo, CA 94580',
#  'City': 'San Lorenzo',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '17321 Hesperian Blvd, San Lorenzo, CA 94580, USA',
#  'Instructor': 'JIKJN Seyd Saidi',
#  'Latitude': '37.6754299',
#  'Longitude': '-122.1245023',
#  'Phone #s': '(510) 276-3834',
#  'Region': 'California'}
# {'Address': '31 West 25th Avenue San Mateo, CA',
#  'City': 'San Mateo',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '31 W 25th Ave, San Mateo, CA 94403, USA',
#  'Instructor': 'JIKJN Tim Sheehan',
#  'Latitude': '37.5437417',
#  'Longitude': '-122.3064776',
#  'Phone #s': '(650) 570-5991',
#  'Region': 'California'}
# {'Address': '27831 Smyth Drive Valencia, CA 91355',
#  'City': 'Santa Clarita',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '27831 Smyth Dr, Valencia, CA 91355, USA',
#  'Instructor': 'Inst. Sydney Albert',
#  'Latitude': '34.4395613',
#  'Longitude': '-118.5663097',
#  'Phone #s': '(661) 523-3455',
#  'Region': 'California'}
# {'Address': 'New Location! Sherman Oaks East Valley Adult Center 5056 Van Nuys Boulevard Van Nuys, CA 91403',
#  'City': 'Sherman Oaks',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '5056 Van Nuys Blvd, Sherman Oaks, CA 91403, USA',
#  'Instructor': 'Inst. Christa Wilson',
#  'Latitude': '34.1631891',
#  'Longitude': '-118.44838',
#  'Phone #s': '(818) 859-2670',
#  'Region': 'California'}
# {'Address': 'NEW!!! 13788A Foothill Blvd. Sylmar, CA 91342',
#  'City': 'Sylmar',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '13788 Foothill Blvd, Sylmar, CA 91342, USA',
#  'Instructor': 'Inst. Nathan Hemmens',
#  'Latitude': '34.3097432',
#  'Longitude': '-118.4335721',
#  'Phone #s': '(818) 939-8800',
#  'Region': 'California'}
# {'Address': '189 Leland Ave St San Fransico, CA',
#  'City': 'Visitacion Valley',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '189 Leland Ave, San Francisco, CA 94134, USA',
#  'Instructor': 'Inst. Jorge Liberona',
#  'Latitude': '37.7124363',
#  'Longitude': '-122.4072425',
#  'Phone #s': '(415) 298-5360',
#  'Region': 'California'}
# {'Address': '420 Front Street Wheatland, CA 95692',
#  'City': 'Wheatland',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '420 Front St, Wheatland, CA 95692, USA',
#  'Instructor': 'PKJN Rick Cairnes',
#  'Latitude': '39.0105021',
#  'Longitude': '-121.4227833',
#  'Phone #s': '(530) 713-2379',
#  'Region': 'California'}
# {'Address': '618 Cottonwood St. Woodland, CA',
#  'City': 'Woodland',
#  'Geocode Type': 'RANGE_INTERPOLATED',
#  'Google Address': '618 Cottonwood St, Woodland, CA 95695, USA',
#  'Instructor': 'PKJN Justin Bunn',
#  'Latitude': '38.67345419999999',
#  'Longitude': '-121.7933617',
#  'Phone #s': '(530) 406-0618',
#  'Region': 'California'}
# {'Address': '236 Bridge St. Yuba City, CA 95991',
#  'City': 'Yuba City',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '236 Bridge St, Yuba City, CA 95991, USA',
#  'Instructor': 'PKJN Daniel Tejada',
#  'Latitude': '39.1373965',
#  'Longitude': '-121.6087783',
#  'Phone #s': '(530) 821-2275',
#  'Region': 'California'}
# {'Address': '3112 Cavanaugh Road Fort Smith, AR 72903',
#  'City': 'Fort Smith (River Valley)',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '3112 Cavanaugh Rd, Fort Smith, AR 72908, USA',
#  'Instructor': 'JIKJN Mike Gray',
#  'Latitude': '35.3112678',
#  'Longitude': '-94.4016202',
#  'Phone #s': '(479) 649-3542',
#  'Region': 'Arkansas'}
# {'Address': 'University of Arkansas 5210 Grand Ave Ft Smith, AR 72913',
#  'City': 'Ft. Smith',
#  'Geocode Type': 'APPROXIMATE',
#  'Google Address': 'Fort Smith, AR, USA',
#  'Instructor': 'JDKJN Jerry Sallee',
#  'Latitude': '35.3859242',
#  'Longitude': '-94.39854749999999',
#  'Phone #s': '(479) 883-6456',
#  'Region': 'Arkansas'}
# {'Address': '1507 Highway 10 Greenwood, AR',
#  'City': 'Greenwood',
#  'Geocode Type': 'RANGE_INTERPOLATED',
#  'Google Address': '1507 AR-10, Greenwood, AR 72936, USA',
#  'Instructor': 'JIKJN Tim Nixon',
#  'Latitude': '35.2038377',
#  'Longitude': '-94.2820811',
#  'Phone #s': '(479) 806-4066',
#  'Region': 'Arkansas'}
# {'Address': '210 Martin St Jacksonville, AR 72076',
#  'City': 'Jacksonville',
#  'Geocode Type': 'APPROXIMATE',
#  'Google Address': 'Jacksonville, AR, USA',
#  'Instructor': 'PKJN Cleo Randall',
#  'Latitude': '34.8662005',
#  'Longitude': '-92.1101458',
#  'Phone #s': '(501) 952-0423',
#  'Region': 'Arkansas'}
# {'Address': 'NEW! Baptist Church 220 Elm Street Mountainburg, AR 72946',
#  'City': 'Mountainburg',
#  'Geocode Type': 'APPROXIMATE',
#  'Google Address': 'Mountainburg, AR 72946, USA',
#  'Instructor': 'JDKJN Jerry Sallee',
#  'Latitude': '35.6356396',
#  'Longitude': '-94.167428',
#  'Phone #s': '(479) 883-6456',
#  'Region': 'Arkansas'}
# {'Address': '4106 Honeysuckle Rogers, AR 72758',
#  'City': 'Rogers',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '4106 Honeysuckle Ln, Rogers, AR 72758, USA',
#  'Instructor': 'PKJN Eric Spivey',
#  'Latitude': '36.2829494',
#  'Longitude': '-94.1274692',
#  'Phone #s': '(479) 986-8000',
#  'Region': 'Arkansas'}
# {'Address': 'Aderholt Fitness Center 259 Tully Street - Bldg 90517 Hurlburt Field, FL 32544',
#  'City': 'Hurlburt Field',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '259 Tully St, Hurlburt Field, FL 32544, USA',
#  'Instructor': 'PKJN Amado Garcia',
#  'Latitude': '30.4230603',
#  'Longitude': '-86.7053961',
#  'Phone #s': '(850) 543-1986;(407) 443-3387',
#  'Region': 'Florida'}
# {'Address': 'NEW!!! Belle Terre Swim and Racquet Club 73 Patricia Drive Palm Coast, FL 32164',
#  'City': 'Palm Coast',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '73 Patricia Dr, Palm Coast, FL 32164, USA',
#  'Instructor': 'PKJN Tim Webster',
#  'Latitude': '29.5389158',
#  'Longitude': '-81.2211286',
#  'Phone #s': '(315) 729-2202',
#  'Region': 'Florida'}
# {'Address': '835 Gretna Blvd Gretna, LA 70053',
#  'City': 'Gretna',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '835 Gretna Blvd, Gretna, LA 70053, USA',
#  'Instructor': 'Inst. Ryan Tardiff',
#  'Latitude': '29.89636',
#  'Longitude': '-90.04982',
#  'Phone #s': '(504) 365-0111',
#  'Region': 'Louisiana'}
# {'Address': 'International School of New Orleans 1400 Camp Street New Orleans, LA 70103',
#  'City': 'Uptown New Orleans',
#  'Geocode Type': 'APPROXIMATE',
#  'Google Address': 'Uptown/Carrollton, New Orleans, LA, USA',
#  'Instructor': 'Inst. Quan Le',
#  'Latitude': '29.9393052',
#  'Longitude': '-90.12142349999999',
#  'Phone #s': '(504) 236-8036',
#  'Region': 'Louisiana'}
# {'Address': 'NEW!!! Xavier University 1 Drexel Drive New Orleans, LA 70125',
#  'City': 'Xavier University',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1 Drexel Dr, New Orleans, LA 70125, USA',
#  'Instructor': 'Inst. Francisco Miramontes',
#  'Latitude': '29.963863',
#  'Longitude': '-90.107084',
#  'Phone #s': '(806) 577-8006',
#  'Region': 'Louisiana'}
# {'Address': 'Pryor Creek Recreational Center 1111 Southeast 9th Street Pryor, OK 74361',
#  'City': 'Pryor',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1111 SE 9th St, Pryor, OK 74361, USA',
#  'Instructor': 'Inst. Michelle Brasher',
#  'Latitude': '36.2942055',
#  'Longitude': '-95.30378739999999',
#  'Phone #s': '(918) 344-9483',
#  'Region': 'Oklahoma'}
# {'Address': 'NEW location! 2051 Mahaney Ave. Tahlequah, OK 74464',
#  'City': 'Tahlequah',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '2051 Mahaney Ave, Tahlequah, OK 74464, USA',
#  'Instructor': 'Inst. Trevor Crouch',
#  'Latitude': '35.889444',
#  'Longitude': '-94.9738065',
#  'Phone #s': '(918) 457-9440',
#  'Region': 'Oklahoma'}
# {'Address': 'NEW !!! Tinker Youth Center 4460 McNarney Ave Oklahoma City, OK 73145',
#  'City': 'Tinker AFB',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': 'Tinker Air Force Base, 4460 McNarney Ave, Oklahoma City, OK 73145, United States',
#  'Instructor': 'Inst. Michael Grimes',
#  'Latitude': '35.4214746',
#  'Longitude': '-97.41805140000001',
#  'Phone #s': '(405) 371-5592',
#  'Region': 'Oklahoma'}
# {'Address': '1107 North Murray Ave. Anderson, SC 29621',
#  'City': 'Anderson',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1107 N Murray Ave, Anderson, SC 29625, USA',
#  'Instructor': 'JDKJN Daniel Middleton',
#  'Latitude': '34.512242',
#  'Longitude': '-82.65543799999999',
#  'Phone #s': '(864) 360-0174',
#  'Region': 'South carolina'}
# {'Address': '1085 Old Clemson Hwy Seneca, SC 29672',
#  'City': 'Clemson',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1085 Old Clemson Hwy, Seneca, SC 29672, USA',
#  'Instructor': 'Inst. Sarah Gordinier',
#  'Latitude': '34.69688319999999',
#  'Longitude': '-82.87710120000001',
#  'Phone #s': '(864) 653-0570',
#  'Region': 'South carolina'}
# {'Address': '3015#C East Palmetto Street Florence, SC',
#  'City': 'Florence',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '3015C E Palmetto St, Florence, SC 29506, USA',
#  'Instructor': 'PKJN. Cliff Bailey',
#  'Latitude': '34.1973569',
#  'Longitude': '-79.707077',
#  'Phone #s': '(843) 665-2100',
#  'Region': 'South carolina'}
# {'Address': '5314 Wade Hampton Blvd.  Taylors, SC 29687',
#  'City': 'Greenville',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '5314 Wade Hampton Blvd, Taylors, SC 29687, USA',
#  'Instructor': 'PKJN. Toan Pham',
#  'Latitude': '34.933851',
#  'Longitude': '-82.28086069999999',
#  'Phone #s': '(864) 517-8075',
#  'Region': 'South carolina'}
# {'Address': 'Carolina School of Massage 1313A Miller Rd. Greenville, SC 29607',
#  'City': 'Greenville',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '210 Adley Way, Greenville, SC 29607, USA',
#  'Instructor': 'JDKJN Daniel Middleton',
#  'Latitude': '34.819153',
#  'Longitude': '-82.28493499999999',
#  'Phone #s': '(864) 860-0174',
#  'Region': 'South carolina'}
# {'Address': 'NEW!! 416 West Main Street Lake City, SC 29560',
#  'City': 'Lake City',
#  'Geocode Type': 'RANGE_INTERPOLATED',
#  'Google Address': '416 W Main St, Lake City, SC 29560, USA',
#  'Instructor': 'Inst. Amber Dickerson',
#  'Latitude': '33.8783001',
#  'Longitude': '-79.7691494',
#  'Phone #s': '',
#  'Region': 'South carolina'}
# {'Address': 'TENNESSEE University of Memphis Memphis, TN 38104',
#  'City': 'University of Memphis',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '3720 Alumni Ave, Memphis, TN 38152, USA',
#  'Instructor': 'Inst. Michael Monahan',
#  'Latitude': '35.118741',
#  'Longitude': '-89.937141',
#  'Phone #s': '(414) 467-3613',
#  'Region': 'South carolina'}
# {'Address': '2401 S. 7th Abilene, TX 79605',
#  'City': 'Abilene',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '2401 S 7th St, Abilene, TX 79605, USA',
#  'Instructor': 'JIKJN Phillip Sage',
#  'Latitude': '32.443481',
#  'Longitude': '-99.7514453',
#  'Phone #s': '(325) 692-0100',
#  'Region': 'Texas'}
# {'Address': '900 FM 1462 ALVIN, TX 77511',
#  'City': 'ALVIN',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '900 FM 1462, Alvin, TX 77511, USA',
#  'Instructor': 'Instr. Joseph Perkins',
#  'Latitude': '29.4016125',
#  'Longitude': '-95.246607',
#  'Phone #s': '(281) 742-4292',
#  'Region': 'Texas'}
# {'Address': 'AUSTIN EANES SCHOOL DISTRICT 601 Camp Craft Rd Austin, TX 78746',
#  'City': 'AUSTIN (EISD)',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '601 Camp Craft Rd, Austin, TX 78746, USA',
#  'Instructor': 'Inst. Darryl Gholston',
#  'Latitude': '30.2781556',
#  'Longitude': '-97.8164506',
#  'Phone #s': '(937) 369-1136',
#  'Region': 'Texas'}
# {'Address': '6001 W. Williams Cannon, Suite 307 Austin, TX 78749',
#  'City': 'Austin (Oak Hill)',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '6001 W William Cannon Dr #307, Austin, TX 78749, USA',
#  'Instructor': 'PKJN Timothy King',
#  'Latitude': '30.2280988',
#  'Longitude': '-97.86284959999999',
#  'Phone #s': '(512) 899-8710',
#  'Region': 'Texas'}
# {'Address': '2827 North Alexander Baytown, TX 77520',
#  'City': 'Baytown',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '2827 N Alexander Dr, Baytown, TX 77520, USA',
#  'Instructor': 'PKJN Tommy Nance',
#  'Latitude': '29.7526537',
#  'Longitude': '-94.94438459999999',
#  'Phone #s': '(281) 428-4930',
#  'Region': 'Texas'}
# {'Address': 'OPEN SOON ! 37131 IH 10 West Boerne, TX 78006',
#  'City': 'Boerne',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '37131 I-10, Boerne, TX 78006, USA',
#  'Instructor': 'inst. Kenneth Thibodeaux',
#  'Latitude': '29.7966293',
#  'Longitude': '-98.75411509999999',
#  'Phone #s': '(210) 912-4300',
#  'Region': 'Texas'}
# {'Address': '1601 Alton Gloor Suite 110 Brownsville, TX 78521',
#  'City': 'Brownsville',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1601 E Alton Gloor Blvd #110, Brownsville, TX 78526, USA',
#  'Instructor': 'PKJN Raul Sosa III',
#  'Latitude': '25.9824391',
#  'Longitude': '-97.4857078',
#  'Phone #s': '(956) 372-1664',
#  'Region': 'Texas'}
# {'Address': 'Coming Soon in August 2017!  4747 FM 1463 Suite #900 Katy, Texas 77494',
#  'City': 'Cinco Ranch',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '4747 FM 1463 #900, Katy, TX 77494, USA',
#  'Instructor': 'Inst. Chris Pak',
#  'Latitude': '29.7231705',
#  'Longitude': '-95.845522',
#  'Phone #s': '(713) 231-4632',
#  'Region': 'Texas'}
# {'Address': '15230 HWY 3 Webster, TX 77598',
#  'City': 'Clear Lake',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '15230 TX-3, Webster, TX 77598, USA',
#  'Instructor': 'SSKJN Barry Harmon',
#  'Latitude': '29.5656913',
#  'Longitude': '-95.1447216',
#  'Phone #s': '(281) 486-5425',
#  'Region': 'Texas'}
# {'Address': '4414 Cobalt Cross St. Katy, Texas 77493',
#  'City': 'Katy',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '4414 Cobalt Cross St, Katy, TX 77493, USA',
#  'Instructor': 'PKJN Ron Michael',
#  'Latitude': '29.8377062',
#  'Longitude': '-95.7780279',
#  'Phone #s': '(281) 615-3542',
#  'Region': 'Texas'}
# {'Address': '910 Russell Palmer Road Kingwood, TX 77339-1601',
#  'City': 'Kingwood',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '910 Russell Palmer Rd, Kingwood, TX 77339, USA',
#  'Instructor': 'SIKJN Richard Roper',
#  'Latitude': '30.0640153',
#  'Longitude': '-95.2268715',
#  'Phone #s': '(281) 359-5425',
#  'Region': 'Texas'}
# {'Address': 'World HQ 37937 FM 1774 Magnolia, TX 77355',
#  'City': 'Magnolia',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '37937 FM 1774, Magnolia, TX 77355, USA',
#  'Instructor': '',
#  'Latitude': '30.1906117',
#  'Longitude': '-95.7186761',
#  'Phone #s': '(832) 934-1400',
#  'Region': 'Texas'}
# {'Address': 'Murphy Community Center  205 N Murphy Road Murphy, TX 75094',
#  'City': 'Murphy (Dallas)',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '205 N Murphy Rd, Murphy, TX 75094, USA',
#  'Instructor': 'Inst. Hong  Cho',
#  'Latitude': '33.016583',
#  'Longitude': '-96.613559',
#  'Phone #s': '(972) 767-9062',
#  'Region': 'Texas'}
# {'Address': 'New location to be announced soon.',
#  'City': 'Pearland',
#  'Geocode Type': 'APPROXIMATE',
#  'Google Address': 'Pearland, TX, USA',
#  'Instructor': 'PKJN Alana Groneman',
#  'Latitude': '29.5635666',
#  'Longitude': '-95.2860474',
#  'Phone #s': '',
#  'Region': 'Texas'}
# {'Address': '114 W. Broadway Street Prosper, TX 75078 Dallas Metro Area',
#  'City': 'Prosper (Dallas)',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '114 W Broadway St, Prosper, TX 75078, USA',
#  'Instructor': 'Inst. Wendy Herrmann',
#  'Latitude': '33.2364694',
#  'Longitude': '-96.80278179999999',
#  'Phone #s': '(469) 307-9940',
#  'Region': 'Texas'}
# {'Address': '1125 Crabb River Road Richmond, TX 77469',
#  'City': 'Richmond',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1125 Crabb River Rd, Richmond, TX 77469, USA',
#  'Instructor': 'Inst. Robert Kuemmel',
#  'Latitude': '29.5511454',
#  'Longitude': '-95.697699',
#  'Phone #s': '(832) 595-2299',
#  'Region': 'Texas'}
# {'Address': '6812 Bandera Rd #109 San Antonio, TX 78238-3552',
#  'City': 'San Antonio',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '6812 Bandera Rd #109, San Antonio, TX 78238, USA',
#  'Instructor': 'JIKJN Daniel Jolly',
#  'Latitude': '29.4979371',
#  'Longitude': '-98.6236093',
#  'Phone #s': '(210) 520-0432',
#  'Region': 'Texas'}
# {'Address': '1149 Harry Wurzbach Rd. San Antonio, TX 78209-640 210-824-KICK(5425)',
#  'City': 'San Antonio (Alamo Heights)',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1149 Harry Wurzbach Rd, San Antonio, TX 78209, USA',
#  'Instructor': 'PKJN Frankie Cade',
#  'Latitude': '29.4699256',
#  'Longitude': '-98.43833540000001',
#  'Phone #s': '',
#  'Region': 'Texas'}
# {'Address': '5530 Walzem Road San Antonio, TX 78218',
#  'City': 'San Antonio (Walzem)',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '5530 Walzem Rd, San Antonio, TX 78218, USA',
#  'Instructor': 'PKJN Lawson Plummer',
#  'Latitude': '29.5102815',
#  'Longitude': '-98.3792684',
#  'Phone #s': '(210) 599-8211',
#  'Region': 'Texas'}
# {'Address': 'Coming soon in September 2017 1330 Aquarena Springs Dr. Suite 107 San Marcos, TX 78666',
#  'City': 'San Marcos',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '1330 Aquarena Springs Dr #107, San Marcos, TX 78666, USA',
#  'Instructor': 'Inst. Eric Morales',
#  'Latitude': '29.8921487',
#  'Longitude': '-97.9219639',
#  'Phone #s': '(512) 997-8052',
#  'Region': 'Texas'}
# {'Address': 'New Location!!! 506 Sawdust Road The Woodlands, TX 77380',
#  'City': 'The Woodlands East',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '506 Sawdust Rd, Spring, TX 77380, USA',
#  'Instructor': 'Inst. Todd Thurman',
#  'Latitude': '30.1284277',
#  'Longitude': '-95.4503443',
#  'Phone #s': '(713) 937-7885',
#  'Region': 'Texas'}
# {'Address': '32215 Tamina Road Magnolia, TX 77354',
#  'City': 'The Woodlands West',
#  'Geocode Type': 'ROOFTOP',
#  'Google Address': '32215 Tamina Rd, Magnolia, TX 77354, USA',
#  'Instructor': 'JIKJN Joseph Foster',
#  'Latitude': '30.2097493',
#  'Longitude': '-95.5775839',
#  'Phone #s': '(281) 259-6333',
#  'Region': 'Texas'}
# {'Address': '20295 F.M.2920 Rd. Tomball, TX 77377',
#  'City': 'Tomball',
#  'Geocode Type': 'RANGE_INTERPOLATED',
#  'Google Address': '20295 Farm to Market 2920, Hockley, TX 77447, USA',
#  'Instructor': 'SIKJN Alex Suh',
#  'Latitude': '30.0791333',
#  'Longitude': '-95.7397678',
#  'Phone #s': '(281) 255-4321',
#  'Region': 'Texas'}
