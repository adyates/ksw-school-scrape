# %%
## Fetch the most recent school data information
import fetch
fetch.fetchData()

# %%
import geocoder
geocoder.loadSchoolData()

# %%
import csv

import ipyleaflet
from ipyleaflet import Map, Marker, MarkerCluster

import geocoder


m = Map(center=[38, -95], zoom=4)

markers = []
with open(geocoder.SCHOOL_GEODATA_FILE, 'rb') as csv_in:
    school_data = csv.DictReader(csv_in)
    for school in school_data:
        marker = Marker(location=(school['Latitude'], school['Longitude']), title=school['Address'])
        markers.append(marker)
        
for marker in markers:
    m += marker
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map data (c) <a href="https://openstreetmap.org">OpenStreetMap</a> contributors'}, center=[38, -95], layers=(TileLayer(base=True, max_zoom=19, min_zoom=1, options=[u'attribution', u'tile_size', u'min_zoom', u'max_zoom', u'detect_retina']), Marker(location=['40.1007672', '-88.23603399999999'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'University of Illinois 201 E. Peabody Champaign, IL'), Marker(location=['42.2591096', '-88.3687126'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'Mc Henry County College 8900 US Hwy 14 Crystal Lke, IL 60012'), Marker(location=['40.947592', '-90.3643311'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'415 East Main Street Galesburg, IL 61401'), Marker(location=['42.3712876', '-87.9175909'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'4628 Old Grand Ave Gurnee. IL 60031'), Marker(location=['40.9083715', '-90.28484759999999'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'220 West Side Public Square Knoxville, Il 61448'), Marker(location=['40.9174656', '-90.6471098'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'NEW!!! 120 East Euclid Avenue Monmouth, IL 61462'), Marker(location=['40.5986511', '-89.6380361'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'1530 N. 8th Street off Route 29 Pekin, IL 61554'), Marker(location=['40.7513381', '-89.6366572'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'5221 N. Big Hollow Road Peoria, IL 61615'), Marker(location=['40.70333309999999', '-89.4260867'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'NEW!! 1227 Peoria Street Washington, IL 61571'), Marker(location=['39.67671', '-85.137948'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'3542 Western Ave Connersville, IN 47331'), Marker(location=['40.1869376', '-85.4113935'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'2190 West White River Bend Blvd. Suite B Muncie, IN 47303'), Marker(location=['39.815155', '-84.88579179999999'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'2023 Chester Blvd (YMCA) Richmond, IN 47374'), Marker(location=['41.5547403', '-90.51666349999999'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'1018 Spruce Hills Dr Bettendorf, IA 52722'), Marker(location=['41.6013233', '-90.3467074'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'427 North 3rd Street Le Claire, IA 52753'), Marker(location=['43.034365', '-83.59671469999999'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'5515 Davison Rd #7 Burton, MI 48509'), Marker(location=['42.4897196', '-83.1054939'], options=[u'rise_offset', u'title', u'z_index_offset', u'draggable', u'keyboard', u'clickable', u'alt', u'rise_on_hover'], title=u'26751 John Road Madison Heights, MI 48071'), Marker(locati ...
